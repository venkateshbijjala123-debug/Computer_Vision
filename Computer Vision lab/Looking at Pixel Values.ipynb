# %%
# Getting Pixel Values
from skimage import io
import pandas as pd

# Use raw string to avoid unicode escape errors
img = io.imread(r'C:\Users\venka\Downloads\Computer Vision lab\images.jpg')

# Flatten pixel values into a single column
df = pd.DataFrame(img.flatten())

# Save to Excel (requires openpyxl, which you now have)
filepath = 'pixel_values1.xlsx'
df.to_excel(filepath, index=False)
