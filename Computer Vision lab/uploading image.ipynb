# %%
from skimage import io
import matplotlib.pyplot as plt

# Load the image
img = io.imread(r'C:\Users\venka\Downloads\god image.webp')

# Display using matplotlib
plt.imshow(img)
plt.axis('off')   # hides axes
plt.show()
